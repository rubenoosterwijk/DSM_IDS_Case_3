# %% [markdown]
# Waar gaan we op focussen:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import folium

# %%
df = pd.read_csv('laadpaallocaties.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Columns: 107 entries, DataProvider to Connections/3/Comments
# dtypes: bool(1), float64(74), int64(12), object(20)
# memory usage: 207.4+ KB

# %%
nonnullfactor = 0.1

df = df.loc[:, df.isnull().mean() < nonnullfactor]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IsRecentlyVerified              250 non-null    bool
#  1   ID                              250 non-null    int64
#  2   UUID                            250 non-null    object
#  3   DataProviderID                  250 non-null    int64
#  4   OperatorID                      249 non-null    float64
#  5   UsageTypeID                     250 non-null    int64
#  6   AddressInfo/ID                  250 non-null    int64
#  7   AddressInfo/Title               250 non-null    object
#  8   AddressInfo/AddressLine1        250 non-null    object
#  9   AddressInfo/Town                243 non-null    object
#  10  AddressInfo/Postcode            229 non-null    object
#  11  AddressInfo/CountryID           250 non-null    int64
#  12  AddressInfo/Latitude            250 non-null    float64
#  13  AddressInfo/Longitude           250 non-null    float64
#  14  AddressInfo/DistanceUnit        250 non-null    int64
#  15  Connections/0/ID                250 non-null    int64
#  16  Connections/0/ConnectionTypeID  250 non-null    int64
#  17  Connections/0/StatusTypeID      248 non-null    float64
#  18  Connections/0/LevelID           247 non-null    float64
#  19  Connections/0/PowerKW           241 non-null    float64
#  20  Connections/0/CurrentTypeID     233 non-null    float64
#  21  Connections/0/Quantity          239 non-null    float64
#  22  NumberOfPoints                  250 non-null    int64
#  23  StatusTypeID                    250 non-null    int64
#  24  DateLastStatusUpdate            250 non-null    object
#  25  DataQualityLevel                250 non-null    int64
#  26  DateCreated                     250 non-null    object
#  27  SubmissionStatusTypeID          250 non-null    int64
# dtypes: bool(1), float64(8), int64(12), object(7)
# memory usage: 53.1+ KB

# %%
list(df.columns.values)
# Out:
# ['IsRecentlyVerified',
#  'ID',
#  'UUID',
#  'DataProviderID',
#  'OperatorID',
#  'UsageTypeID',
#  'AddressInfo/ID',
#  'AddressInfo/Title',
#  'AddressInfo/AddressLine1',
#  'AddressInfo/Town',
#  'AddressInfo/Postcode',
#  'AddressInfo/CountryID',
#  'AddressInfo/Latitude',
#  'AddressInfo/Longitude',
#  'AddressInfo/DistanceUnit',
#  'Connections/0/ID',
#  'Connections/0/ConnectionTypeID',
#  'Connections/0/StatusTypeID',
#  'Connections/0/LevelID',
#  'Connections/0/PowerKW',
#  'Connections/0/CurrentTypeID',
#  'Connections/0/Quantity',
#  'NumberOfPoints',
#  'StatusTypeID',
#  'DateLastStatusUpdate',
#  'DataQualityLevel',
#  'DateCreated',
#  'SubmissionStatusTypeID']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IsRecentlyVerified              250 non-null    bool
#  1   ID                              250 non-null    int64
#  2   UUID                            250 non-null    object
#  3   DataProviderID                  250 non-null    int64
#  4   OperatorID                      249 non-null    float64
#  5   UsageTypeID                     250 non-null    int64
#  6   AddressInfo/ID                  250 non-null    int64
#  7   AddressInfo/Title               250 non-null    object
#  8   AddressInfo/AddressLine1        250 non-null    object
#  9   AddressInfo/Town                243 non-null    object
#  10  AddressInfo/Postcode            229 non-null    object
#  11  AddressInfo/CountryID           250 non-null    int64
#  12  AddressInfo/Latitude            250 non-null    float64
#  13  AddressInfo/Longitude           250 non-null    float64
#  14  AddressInfo/DistanceUnit        250 non-null    int64
#  15  Connections/0/ID                250 non-null    int64
#  16  Connections/0/ConnectionTypeID  250 non-null    int64
#  17  Connections/0/StatusTypeID      248 non-null    float64
#  18  Connections/0/LevelID           247 non-null    float64
#  19  Connections/0/PowerKW           241 non-null    float64
#  20  Connections/0/CurrentTypeID     233 non-null    float64
#  21  Connections/0/Quantity          239 non-null    float64
#  22  NumberOfPoints                  250 non-null    int64
#  23  StatusTypeID                    250 non-null    int64
#  24  DateLastStatusUpdate            250 non-null    object
#  25  DataQualityLevel                250 non-null    int64
#  26  DateCreated                     250 non-null    object
#  27  SubmissionStatusTypeID          250 non-null    int64
# dtypes: bool(1), float64(8), int64(12), object(7)
# memory usage: 53.1+ KB

# %%
df
# Out:
#      IsRecentlyVerified      ID                                  UUID  \
# 0                  True  173970  66115821-7A60-4291-923E-4D11912AAD7E
# 1                  True  173970  66115821-7A60-4291-923E-4D11912AAD7E
# 2                  True  173931  69E160CA-B1AB-460A-B8FF-96A71CEF1DDE
# 3                  True  173931  69E160CA-B1AB-460A-B8FF-96A71CEF1DDE
# 4                  True  173931  69E160CA-B1AB-460A-B8FF-96A71CEF1DDE
# ..                  ...     ...                                   ...
# 245               False   90554  2BF7C946-E5B1-4921-B1A3-AFEDD2C82387
# 246               False   90311  F5293125-0AA6-4522-997F-C13DD0618844
# 247               False   90203  39B5F6CF-AF3E-4651-9094-9B3104CC209A
# 248               False   88897  0025FB95-727C-42A9-BC04-938C9FC4EA64
# 249               False   88878  12146942-0E5D-4096-A5EE-5DF9A2AB5986
#
#      DataProviderID  OperatorID  UsageTypeID  AddressInfo/ID  \
# 0                 1        73.0            1          174329
# 1                 1        73.0            1          174329
# 2                 1         1.0            1          174290
# 3                 1         1.0            1          174290
# 4                 1         1.0            1          174290
# ..              ...         ...          ...             ...
# 245               1        47.0            6           90900
# 246               1        23.0            7           90657
# 247               1        23.0            6           90549
# 248               1       103.0            1           89243
# 249               1        23.0            6           89224
#
#                       AddressInfo/Title   AddressInfo/AddressLine1  \
# 0                     EVBox fastcharger           Kallenbroekerweg
# 1                     EVBox fastcharger           Kallenbroekerweg
# 2                   AVIA de Poel - Goes   77A Anthony Fokkerstraat
# 3                   AVIA de Poel - Goes   77A Anthony Fokkerstraat
# 4                   AVIA de Poel - Goes   77A Anthony Fokkerstraat
# ..                                  ...                        ...
# 245                       Nassaulaan 36              Nassaulaan 36
# 246          Het Bosch @ the Waterfront               Jollenpad 10
# 247               Logement Aan de Vecht               Straatweg 30
# 248  P-Havenpoort (’s Heer Lauwensdorp)      's Heer Lauwendorp 14
# 249                  Hotel Ibis Tilburg  DR. Hub Van Doorneweg 105
#
#     AddressInfo/Town  ... Connections/0/LevelID  Connections/0/PowerKW  \
# 0          Barneveld  ...                   3.0                   50.0
# 1          Barneveld  ...                   3.0                   50.0
# 2               Goes  ...                   2.0                   11.0
# 3               Goes  ...                   2.0                   11.0
# 4               Goes  ...                   2.0                   11.0
# ..               ...  ...                   ...                    ...
# 245            Baarn  ...                   2.0                   22.0
# 246        Amsterdam  ...                   2.0                   22.0
# 247        Breukelen  ...                   2.0                   22.0
# 248        Zierikzee  ...                   2.0                    NaN
# 249          Tilburg  ...                   2.0                   22.0
#
#      Connections/0/CurrentTypeID  Connections/0/Quantity  NumberOfPoints  \
# 0                           30.0                     1.0               2
# 1                           30.0                     1.0               2
# 2                           10.0                     1.0               1
# 3                           10.0                     1.0               1
# 4                           10.0                     1.0               1
# ..                           ...                     ...             ...
# 245                         20.0                     1.0               1
# 246                         20.0                     2.0               2
# 247                         20.0                     2.0               2
# 248                         20.0                     2.0               2
# 249                         20.0                     1.0               1
#
#      StatusTypeID  DateLastStatusUpdate  DataQualityLevel  \
# 0              50  2021-03-09T22:32:00Z                 1
# 1              50  2021-03-09T22:32:00Z                 1
# 2              50  2021-03-08T10:45:00Z                 1
# 3              50  2021-03-08T10:45:00Z                 1
# 4              50  2021-03-08T10:45:00Z                 1
# ..            ...                   ...               ...
# 245            50  2017-07-20T13:02:00Z                 1
# 246            50  2018-10-03T16:10:00Z                 1
# 247            50  2018-10-03T23:09:00Z                 1
# 248            50  2017-09-19T09:27:00Z                 1
# 249            50  2018-10-03T22:31:00Z                 1
#
#               DateCreated  SubmissionStatusTypeID
# 0    2021-03-08T19:25:00Z                     200
# 1    2021-03-08T19:25:00Z                     200
# 2    2021-03-07T18:44:00Z                     200
# 3    2021-03-07T18:44:00Z                     200
# 4    2021-03-07T18:44:00Z                     200
# ..                    ...                     ...
# 245  2017-07-17T18:41:00Z                     200
# 246  2017-07-13T14:44:00Z                     200
# 247  2017-07-13T14:14:00Z                     200
# 248  2017-06-11T13:28:00Z                     200
# 249  2017-06-09T15:20:00Z                     200
#
# [250 rows x 28 columns]

# %%
df = df.drop_duplicates()
df = df.reset_index(drop=True)
df
# Out:
#      IsRecentlyVerified      ID                                  UUID  \
# 0                  True  173970  66115821-7A60-4291-923E-4D11912AAD7E
# 1                  True  173931  69E160CA-B1AB-460A-B8FF-96A71CEF1DDE
# 2                  True  173900  2CF47245-BB7F-4973-8F7C-7E058F991C8F
# 3                  True  173893  E564B27E-9773-48D9-A9D7-0920F14988CD
# 4                  True  173892  CBED4444-AFF9-4763-87F8-DE4235F01242
# ..                  ...     ...                                   ...
# 227               False   90554  2BF7C946-E5B1-4921-B1A3-AFEDD2C82387
# 228               False   90311  F5293125-0AA6-4522-997F-C13DD0618844
# 229               False   90203  39B5F6CF-AF3E-4651-9094-9B3104CC209A
# 230               False   88897  0025FB95-727C-42A9-BC04-938C9FC4EA64
# 231               False   88878  12146942-0E5D-4096-A5EE-5DF9A2AB5986
#
#      DataProviderID  OperatorID  UsageTypeID  AddressInfo/ID  \
# 0                 1        73.0            1          174329
# 1                 1         1.0            1          174290
# 2                 1       103.0            4          174259
# 3                 1       103.0            4          174252
# 4                 1       103.0            4          174251
# ..              ...         ...          ...             ...
# 227               1        47.0            6           90900
# 228               1        23.0            7           90657
# 229               1        23.0            6           90549
# 230               1       103.0            1           89243
# 231               1        23.0            6           89224
#
#                       AddressInfo/Title   AddressInfo/AddressLine1  \
# 0                     EVBox fastcharger           Kallenbroekerweg
# 1                   AVIA de Poel - Goes   77A Anthony Fokkerstraat
# 2    Ab en van de Schelde Nissan dealer        Nikolaus Ottostraat
# 3    Ab en van de Schelde Nissan dealer        Nikolaus Ottostraat
# 4    Ab en van de Schelde Nissan dealer        Nikolaus Ottostraat
# ..                                  ...                        ...
# 227                       Nassaulaan 36              Nassaulaan 36
# 228          Het Bosch @ the Waterfront               Jollenpad 10
# 229               Logement Aan de Vecht               Straatweg 30
# 230  P-Havenpoort (’s Heer Lauwensdorp)      's Heer Lauwendorp 14
# 231                  Hotel Ibis Tilburg  DR. Hub Van Doorneweg 105
#
#     AddressInfo/Town  ... Connections/0/LevelID  Connections/0/PowerKW  \
# 0          Barneveld  ...                   3.0                   50.0
# 1               Goes  ...                   2.0                   11.0
# 2             Zwolle  ...                   3.0                   50.0
# 3             Zwolle  ...                   3.0                   50.0
# 4             Zwolle  ...                   3.0                   50.0
# ..               ...  ...                   ...                    ...
# 227            Baarn  ...                   2.0                   22.0
# 228        Amsterdam  ...                   2.0                   22.0
# 229        Breukelen  ...                   2.0                   22.0
# 230        Zierikzee  ...                   2.0                    NaN
# 231          Tilburg  ...                   2.0                   22.0
#
#      Connections/0/CurrentTypeID  Connections/0/Quantity  NumberOfPoints  \
# 0                           30.0                     1.0               2
# 1                           10.0                     1.0               1
# 2                           30.0                     1.0               1
# 3                           30.0                     1.0               1
# 4                           30.0                     1.0               1
# ..                           ...                     ...             ...
# 227                         20.0                     1.0               1
# 228                         20.0                     2.0               2
# 229                         20.0                     2.0               2
# 230                         20.0                     2.0               2
# 231                         20.0                     1.0               1
#
#      StatusTypeID  DateLastStatusUpdate  DataQualityLevel  \
# 0              50  2021-03-09T22:32:00Z                 1
# 1              50  2021-03-08T10:45:00Z                 1
# 2              50  2021-03-05T18:16:00Z                 1
# 3              50  2021-03-05T18:01:00Z                 1
# 4              50  2021-03-07T20:26:00Z                 1
# ..            ...                   ...               ...
# 227            50  2017-07-20T13:02:00Z                 1
# 228            50  2018-10-03T16:10:00Z                 1
# 229            50  2018-10-03T23:09:00Z                 1
# 230            50  2017-09-19T09:27:00Z                 1
# 231            50  2018-10-03T22:31:00Z                 1
#
#               DateCreated  SubmissionStatusTypeID
# 0    2021-03-08T19:25:00Z                     200
# 1    2021-03-07T18:44:00Z                     200
# 2    2021-03-05T11:48:00Z                     200
# 3    2021-03-05T10:15:00Z                     200
# 4    2021-03-05T10:13:00Z                     200
# ..                    ...                     ...
# 227  2017-07-17T18:41:00Z                     200
# 228  2017-07-13T14:44:00Z                     200
# 229  2017-07-13T14:14:00Z                     200
# 230  2017-06-11T13:28:00Z                     200
# 231  2017-06-09T15:20:00Z                     200
#
# [232 rows x 28 columns]

# %%
conditions = [
    (df['Connections/0/LevelID'] == 1),
    (df['Connections/0/LevelID'] == 2),
    (df['Connections/0/LevelID'] == 3)
    ]
values = ['Slow Charge AC', 'Fast Charge AC', 'Rapid Charge DC']

df['ChargerType'] = np.select(conditions, values)
df
# Out:
#      IsRecentlyVerified      ID                                  UUID  \
# 0                  True  173970  66115821-7A60-4291-923E-4D11912AAD7E
# 1                  True  173931  69E160CA-B1AB-460A-B8FF-96A71CEF1DDE
# 2                  True  173900  2CF47245-BB7F-4973-8F7C-7E058F991C8F
# 3                  True  173893  E564B27E-9773-48D9-A9D7-0920F14988CD
# 4                  True  173892  CBED4444-AFF9-4763-87F8-DE4235F01242
# ..                  ...     ...                                   ...
# 227               False   90554  2BF7C946-E5B1-4921-B1A3-AFEDD2C82387
# 228               False   90311  F5293125-0AA6-4522-997F-C13DD0618844
# 229               False   90203  39B5F6CF-AF3E-4651-9094-9B3104CC209A
# 230               False   88897  0025FB95-727C-42A9-BC04-938C9FC4EA64
# 231               False   88878  12146942-0E5D-4096-A5EE-5DF9A2AB5986
#
#      DataProviderID  OperatorID  UsageTypeID  AddressInfo/ID  \
# 0                 1        73.0            1          174329
# 1                 1         1.0            1          174290
# 2                 1       103.0            4          174259
# 3                 1       103.0            4          174252
# 4                 1       103.0            4          174251
# ..              ...         ...          ...             ...
# 227               1        47.0            6           90900
# 228               1        23.0            7           90657
# 229               1        23.0            6           90549
# 230               1       103.0            1           89243
# 231               1        23.0            6           89224
#
#                       AddressInfo/Title   AddressInfo/AddressLine1  \
# 0                     EVBox fastcharger           Kallenbroekerweg
# 1                   AVIA de Poel - Goes   77A Anthony Fokkerstraat
# 2    Ab en van de Schelde Nissan dealer        Nikolaus Ottostraat
# 3    Ab en van de Schelde Nissan dealer        Nikolaus Ottostraat
# 4    Ab en van de Schelde Nissan dealer        Nikolaus Ottostraat
# ..                                  ...                        ...
# 227                       Nassaulaan 36              Nassaulaan 36
# 228          Het Bosch @ the Waterfront               Jollenpad 10
# 229               Logement Aan de Vecht               Straatweg 30
# 230  P-Havenpoort (’s Heer Lauwensdorp)      's Heer Lauwendorp 14
# 231                  Hotel Ibis Tilburg  DR. Hub Van Doorneweg 105
#
#     AddressInfo/Town  ... Connections/0/PowerKW  Connections/0/CurrentTypeID  \
# 0          Barneveld  ...                  50.0                         30.0
# 1               Goes  ...                  11.0                         10.0
# 2             Zwolle  ...                  50.0                         30.0
# 3             Zwolle  ...                  50.0                         30.0
# 4             Zwolle  ...                  50.0                         30.0
# ..               ...  ...                   ...                          ...
# 227            Baarn  ...                  22.0                         20.0
# 228        Amsterdam  ...                  22.0                         20.0
# 229        Breukelen  ...                  22.0                         20.0
# 230        Zierikzee  ...                   NaN                         20.0
# 231          Tilburg  ...                  22.0                         20.0
#
#      Connections/0/Quantity  NumberOfPoints  StatusTypeID  \
# 0                       1.0               2            50
# 1                       1.0               1            50
# 2                       1.0               1            50
# 3                       1.0               1            50
# 4                       1.0               1            50
# ..                      ...             ...           ...
# 227                     1.0               1            50
# 228                     2.0               2            50
# 229                     2.0               2            50
# 230                     2.0               2            50
# 231                     1.0               1            50
#
#      DateLastStatusUpdate  DataQualityLevel           DateCreated  \
# 0    2021-03-09T22:32:00Z                 1  2021-03-08T19:25:00Z
# 1    2021-03-08T10:45:00Z                 1  2021-03-07T18:44:00Z
# 2    2021-03-05T18:16:00Z                 1  2021-03-05T11:48:00Z
# 3    2021-03-05T18:01:00Z                 1  2021-03-05T10:15:00Z
# 4    2021-03-07T20:26:00Z                 1  2021-03-05T10:13:00Z
# ..                    ...               ...                   ...
# 227  2017-07-20T13:02:00Z                 1  2017-07-17T18:41:00Z
# 228  2018-10-03T16:10:00Z                 1  2017-07-13T14:44:00Z
# 229  2018-10-03T23:09:00Z                 1  2017-07-13T14:14:00Z
# 230  2017-09-19T09:27:00Z                 1  2017-06-11T13:28:00Z
# 231  2018-10-03T22:31:00Z                 1  2017-06-09T15:20:00Z
#
#      SubmissionStatusTypeID      ChargerType
# 0                       200  Rapid Charge DC
# 1                       200   Fast Charge AC
# 2                       200  Rapid Charge DC
# 3                       200  Rapid Charge DC
# 4                       200  Rapid Charge DC
# ..                      ...              ...
# 227                     200   Fast Charge AC
# 228                     200   Fast Charge AC
# 229                     200   Fast Charge AC
# 230                     200   Fast Charge AC
# 231                     200   Fast Charge AC
#
# [232 rows x 29 columns]

# %%
def color_producer(type):
    if type == "Fast Charge AC":
        return 'red'
    if type == "Rapid Charge DC":
        return 'green'

# %%
# iterate over rows with iterrows()
types = ['Fast Charge AC',
         'Rapid Charge DC']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232 entries, 0 to 231
# Data columns (total 29 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   IsRecentlyVerified              232 non-null    bool
#  1   ID                              232 non-null    int64
#  2   UUID                            232 non-null    object
#  3   DataProviderID                  232 non-null    int64
#  4   OperatorID                      231 non-null    float64
#  5   UsageTypeID                     232 non-null    int64
#  6   AddressInfo/ID                  232 non-null    int64
#  7   AddressInfo/Title               232 non-null    object
#  8   AddressInfo/AddressLine1        232 non-null    object
#  9   AddressInfo/Town                225 non-null    object
#  10  AddressInfo/Postcode            211 non-null    object
#  11  AddressInfo/CountryID           232 non-null    int64
#  12  AddressInfo/Latitude            232 non-null    float64
#  13  AddressInfo/Longitude           232 non-null    float64
#  14  AddressInfo/DistanceUnit        232 non-null    int64
#  15  Connections/0/ID                232 non-null    int64
#  16  Connections/0/ConnectionTypeID  232 non-null    int64
#  17  Connections/0/StatusTypeID      230 non-null    float64
#  18  Connections/0/LevelID           229 non-null    float64
#  19  Connections/0/PowerKW           223 non-null    float64
#  20  Connections/0/CurrentTypeID     215 non-null    float64
#  21  Connections/0/Quantity          221 non-null    float64
#  22  NumberOfPoints                  232 non-null    int64
#  23  StatusTypeID                    232 non-null    int64
#  24  DateLastStatusUpdate            232 non-null    object
#  25  DataQualityLevel                232 non-null    int64
#  26  DateCreated                     232 non-null    object
#  27  SubmissionStatusTypeID          232 non-null    int64
#  28  ChargerType                     232 non-null    object
# dtypes: bool(1), float64(8), int64(12), object(8)
# memory usage: 51.1+ KB

# %%
utrecht = [52.0893191, 5.1101691]
m = folium.Map(location=utrecht, zoom_start=7, tiles="openstreetmap")

loc = 'Laadpalen Nederland'
title_html = '''
             <h3 align="center" style="font-size:16px"><b>{}</b></h3>
             '''.format(loc)   

m.get_root().html.add_child(folium.Element(title_html))

# %%
for x in types:
    
    a = df.loc[(df['ChargerType']  == x)]
    
    feature_group = folium.FeatureGroup(x)

    for index, row in a.iterrows():

        meting = row["Connections/0/PowerKW"]
        metingstr = str(meting)
        message1= 'Klik hier de locatie te zien'
        message = message1 + metingstr
        locatie = [row['AddressInfo/Latitude'], row['AddressInfo/Longitude']]
        adres = row['AddressInfo/AddressLine1'], row["AddressInfo/Postcode"]
        popup = str(adres)
    #     print(locatie)

        folium.CircleMarker(
            location=locatie,
            popup=popup,
            tooltip=message,
            radius=5, 
            color=color_producer(row["ChargerType"]),                            
            fill =True,
            fillOpacity=0.4).add_to(feature_group)
        
    feature_group.add_to(m)

# %%
folium.TileLayer('Stamen Toner', name="Zwart/Wit").add_to(m)
folium.TileLayer('stamenterrain', name="Terrein").add_to(m)
folium.TileLayer('stamenwatercolor', name="Waterverf").add_to(m)

folium.LayerControl().add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b0b957a6432b4713b288e91a35805154%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%3Ch3%20align%3D%22center%22%20style%3D%22font-size%3A16px%22%3E%3Cb%3ELaadpalen%20Nederland%3C/b%3E%3C/h3%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b0b957a6432b4713b288e91a35805154%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b0b957a6432b4713b288e91a35805154%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b0b957a6432b4713b288e91a35805154%22%2C%0A%20%20 ...
